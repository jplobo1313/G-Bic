# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import seaborn as sns

# %%
X = pd.read_csv("./Dataset2_data.tsv",index_col=0, sep = "\t")

# %%
plt.figure()
fig, ax1 = plt.subplots(figsize=(13,7),dpi=80,facecolor='w',edgecolor='k')

sns.heatmap(data=X, cmap = "coolwarm")


fontsize = 20

plt.ylabel('Observations',fontsize=fontsize)
plt.xticks(rotation=90)

plt.xlabel('Attributes',fontsize=fontsize)

l3 = ax1.legend(loc = 'center right', bbox_to_anchor=(1.1,0.5),ncol=1)
fig.tight_layout()

#plt.show()
#plt.savefig("./Figure_1.pdf", dpi=1200, bbox_inches = 'tight')
#plt.close(1)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
l1 = ["x0","x2","x3","x6","x7","x9","x10","x16","x17","x20","x22","x24","x25","x27","x28","x29","x30","x33","x38","x39","x40","x42","x45","x46","x52","x53","x54","x55","x56","x57","x58","x64","x66","x69","x70","x74","x75","x77","x78","x79","x80","x82","x83","x87","x88","x90","x91","x94","x95","x98"]
l3 = ["x0","x2","x3","x4","x6","x7","x8","x9","x10","x12","x13","x16","x17","x18","x19","x20","x22","x23","x24","x25","x27","x28","x29","x30","x32","x33","x36","x37","x38","x39","x40","x41","x42","x44","x45","x46","x49","x51","x52","x60","x61","x65","x72","x73","x86","x89","x92","x93","x97","x99"]




l2 = list(set(l1).intersection(l3))
l1 = list(set(l1) ^ set(l2))
l3 = list(set(l3) ^ set(l2))

print(l1)
print(l2)
print(l3)
# Out:
# ['x64', 'x83', 'x53', 'x87', 'x91', 'x80', 'x77', 'x79', 'x74', 'x57', 'x90', 'x95', 'x70', 'x58', 'x54', 'x69', 'x55', 'x98', 'x56', 'x66', 'x82', 'x75', 'x78', 'x94', 'x88']
# ['x46', 'x16', 'x30', 'x45', 'x3', 'x42', 'x22', 'x27', 'x2', 'x17', 'x0', 'x7', 'x25', 'x28', 'x40', 'x10', 'x52', 'x9', 'x39', 'x29', 'x38', 'x33', 'x20', 'x24', 'x6']
# ['x18', 'x97', 'x99', 'x32', 'x89', 'x93', 'x19', 'x51', 'x44', 'x60', 'x23', 'x41', 'x92', 'x36', 'x61', 'x8', 'x49', 'x65', 'x86', 'x4', 'x13', 'x73', 'x72', 'x37', 'x12']

# %%
l4 = l1 + l2 + l3 

List = list(X.drop(labels= l4).index)


NewList = List[0:10] + l4 + List[10:len(List)] 

X2 = X.reindex(NewList)

# %%
plt.figure()
fig, ax1 = plt.subplots(figsize=(13,7),dpi=80,facecolor='w',edgecolor='k')

sns.heatmap(data=X2, cmap = "coolwarm")


fontsize = 20

plt.ylabel('Observations',fontsize=fontsize)
plt.xticks(rotation=90)

plt.xlabel('Attributes',fontsize=fontsize)

l3 = ax1.legend(loc = 'center right', bbox_to_anchor=(1.1,0.5),ncol=1)
fig.tight_layout()

plt.show()
#plt.close(1)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
l1 = ["y0","y1","y3","y4","y6","y10","y11","y14","y15","y17","y20","y21","y22","y25","y27","y29","y30","y32","y38","y39","y42","y43","y46","y47","y48","y50","y52","y54","y55","y56","y57","y59","y60","y61","y62","y63","y65","y69","y75","y78","y84","y86","y89","y91","y92","y93","y94","y96","y97","y98"]
l3 = ["y0","y1","y2","y3","y4","y5","y6","y8","y10","y11","y12","y14","y15","y16","y17","y18","y20","y21","y22","y23","y24","y25","y27","y29","y30","y32","y35","y38","y39","y40","y42","y43","y46","y47","y48","y49","y53","y66","y67","y68","y70","y72","y74","y76","y82","y83","y85","y90","y95","y99"]



l2 = list(set(l1).intersection(l3))
l1 = list(set(l1) ^ set(l2))
l3 = list(set(l3) ^ set(l2))

print(l1)
print(l2)
print(l3)
# Out:
# ['y55', 'y60', 'y89', 'y98', 'y63', 'y62', 'y97', 'y86', 'y93', 'y59', 'y69', 'y56', 'y94', 'y61', 'y57', 'y54', 'y84', 'y91', 'y78', 'y96', 'y92', 'y50', 'y65', 'y52', 'y75']
# ['y46', 'y15', 'y0', 'y47', 'y10', 'y11', 'y38', 'y27', 'y20', 'y43', 'y3', 'y30', 'y14', 'y48', 'y25', 'y1', 'y42', 'y17', 'y21', 'y22', 'y4', 'y6', 'y39', 'y29', 'y32']
# ['y8', 'y16', 'y85', 'y68', 'y90', 'y2', 'y74', 'y67', 'y53', 'y82', 'y35', 'y40', 'y5', 'y72', 'y95', 'y24', 'y66', 'y76', 'y83', 'y18', 'y49', 'y23', 'y70', 'y12', 'y99']

# %%
X3 = X2.T


l4 = l1 + l2 + l3


List = list(X3.drop(labels=l4).index)

NewList = List[0:10] + l4 + List[10:len(List)] 

X4 = X3.reindex(NewList)

# %%
plt.figure()
fig, ax1 = plt.subplots(figsize=(13,7),dpi=80,facecolor='w',edgecolor='k')

sns.heatmap(data=X4.T, cmap = "coolwarm")


fontsize = 20

plt.ylabel('Observations',fontsize=fontsize)
plt.xticks(rotation=90)

plt.xlabel('Attributes',fontsize=fontsize)

l3 = ax1.legend(loc = 'center right', bbox_to_anchor=(1.1,0.5),ncol=1)
fig.tight_layout()


#plt.show()

plt.savefig("./Figure_1.pdf", dpi=1200, bbox_inches = 'tight')
#plt.close(1)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
